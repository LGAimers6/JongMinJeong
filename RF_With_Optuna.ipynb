# %%
import pandas as pd 

df = pd.read_csv(r'C:\Users\User\LG_Aimers\MainTask\train.csv')

# %%
def age_encoding(age):
    if age == "만18-34세":
        return 0
    elif age == "만35-37세":
        return 1
    elif age == "만38-39세":
        return 2
    elif age == "만40-42세":
        return 3
    elif age == "만43-44세":
        return 4
    elif age == "만45-50세":
        return 5
    else:
        return None  # 그 외 값은 None으로 처리

df.loc[:,'시술 당시 나이'] = df['시술 당시 나이'].apply(age_encoding)

# %%
df = df[['시술 당시 나이',
                    '시술 유형',
                    '특정 시술 유형',
                    '배란 자극 여부',
                    '이식된 배아 수',
                    '단일 배아 이식 여부',
                    '착상 전 유전 검사 사용 여부',
                    '착상 전 유전 진단 사용 여부',
                    #네이쳐지에서는 Infertility Cause Feature에서
                    #Cause of Infertility - Endometriosis같은 3~4개정도의 Feature는 제외했던데 
                    #Frontier에서는 ML로 결측치 처리하니까 되도록 다양한 Feature를 넣을 것을 권장
                    #상황에 따라서 빼거나 넣기
                    '남성 주 불임 원인',
                    '남성 부 불임 원인',
                    '여성 주 불임 원인',
                    '여성 부 불임 원인',
                    '부부 주 불임 원인',
                    '부부 부 불임 원인',
                    '불명확 불임 원인',
                    '불임 원인 - 난관 질환',
                    '불임 원인 - 남성 요인',
                    '불임 원인 - 배란 장애',
                    '불임 원인 - 여성 요인',
                    '불임 원인 - 자궁경부 문제',
                    '불임 원인 - 자궁내막증',
                    '불임 원인 - 정자 면역학적 요인',
                    '불임 원인 - 정자 운동성',
                    '불임 원인 - 정자 형태',                       
                    #------------------------------------------------------
                    
                    '총 시술 횟수',
                    '클리닉 내 총 시술 횟수',
                    'IVF 시술 횟수',
                    'DI 시술 횟수',
                    '총 임신 횟수',
                    'IVF 임신 횟수',
                    'DI 임신 횟수',
                    '총 출산 횟수',
                    'IVF 출산 횟수',
                    'DI 출산 횟수',
                    '총 생성 배아 수',
                    '미세주입된 난자 수',
                    '미세주입에서 생성된 배아 수',
                    '이식된 배아 수',
                    '미세주입 배아 이식 수',
                    '저장된 배아 수',
                    '미세주입 후 저장된 배아 수',
                    '해동된 배아 수',
                    '해동 난자 수',
                    '수집된 신선 난자 수',
                    '저장된 신선 난자 수',
                    '혼합된 난자 수',
                    '파트너 정자와 혼합된 난자 수',
                    '기증자 정자와 혼합된 난자 수',
                    '난자 출처',
                    '정자 출처',
                    '난자 기증자 나이',
                    '정자 기증자 나이',
                    '동결 배아 사용 여부',
                    '신선 배아 사용 여부',
                    '기증 배아 사용 여부',
                    '대리모 여부',
                    #경우에 따라서 삭제 or 삽입
                    'PGD 시술 여부',
                    'PGS 시술 여부',
                    #---------------------------
                    '난자 채취 경과일',
                    #경우에 따라서 삭제 or 삽입
                    '난자 해동 경과일',
                    #---------------------------
                    '난자 혼합 경과일',
                    '배아 이식 경과일',
                    #경우에 따라서 삭제 or 삽입
                    '배아 해동 경과일',
                    #---------------------------
                    '임신 성공 여부'
                  ]]

# %%
df
# Out:
#        시술 당시 나이 시술 유형 특정 시술 유형  배란 자극 여부  이식된 배아 수  단일 배아 이식 여부  \
# 0           0.0   IVF     ICSI         1       2.0          0.0
# 1           5.0   IVF     ICSI         0       0.0          0.0
# 2           0.0   IVF      IVF         1       2.0          0.0
# 3           1.0   IVF     ICSI         1       0.0          0.0
# 4           0.0   IVF     ICSI         1       2.0          0.0
# ...         ...   ...      ...       ...       ...          ...
# 256346      0.0   IVF     ICSI         1       2.0          0.0
# 256347      2.0   IVF     ICSI         1       2.0          0.0
# 256348      1.0   IVF     ICSI         1       2.0          0.0
# 256349      2.0   IVF     ICSI         1       2.0          0.0
# 256350      1.0   IVF      IVF         0       2.0          0.0
#
#         착상 전 유전 검사 사용 여부  착상 전 유전 진단 사용 여부  남성 주 불임 원인  남성 부 불임 원인  ...  \
# 0                    NaN               0.0           0           0  ...
# 1                    NaN               0.0           0           0  ...
# 2                    NaN               0.0           0           0  ...
# 3                    NaN               0.0           0           0  ...
# 4                    NaN               0.0           0           0  ...
# ...                  ...               ...         ...         ...  ...
# 256346               NaN               0.0           0           0  ...
# 256347               NaN               0.0           0           0  ...
# 256348               NaN               0.0           0           0  ...
# 256349               NaN               0.0           0           0  ...
# 256350               NaN               0.0           0           0  ...
#
#         기증 배아 사용 여부  대리모 여부  PGD 시술 여부  PGS 시술 여부  난자 채취 경과일  난자 해동 경과일  \
# 0               0.0     0.0        NaN        NaN        0.0        NaN
# 1               0.0     0.0        NaN        NaN        0.0        NaN
# 2               0.0     0.0        NaN        NaN        0.0        NaN
# 3               0.0     0.0        NaN        NaN        0.0        NaN
# 4               0.0     0.0        NaN        NaN        0.0        NaN
# ...             ...     ...        ...        ...        ...        ...
# 256346          0.0     0.0        NaN        NaN        0.0        NaN
# 256347          0.0     0.0        NaN        NaN        0.0        NaN
# 256348          0.0     0.0        NaN        NaN        0.0        NaN
# 256349          0.0     0.0        NaN        NaN        0.0        NaN
# 256350          0.0     0.0        NaN        NaN        NaN        NaN
#
#         난자 혼합 경과일  배아 이식 경과일  배아 해동 경과일  임신 성공 여부
# 0             0.0        3.0        NaN         0
# 1             0.0        NaN        NaN         0
# 2             0.0        2.0        NaN         0
# 3             0.0        NaN        NaN         0
# 4             0.0        3.0        NaN         0
# ...           ...        ...        ...       ...
# 256346        0.0        5.0        NaN         0
# 256347        0.0        3.0        NaN         1
# 256348        0.0        3.0        NaN         0
# 256349        0.0        1.0        NaN         1
# 256350        NaN        0.0        0.0         1
#
# [256351 rows x 64 columns]

# %%
import numpy as np
import pandas as pd
from minisom import MiniSom
from sklearn.impute import SimpleImputer

# %%
def removeHangual(tmp):
    return int(tmp[0])
df.loc[:,['총 시술 횟수']] = df['총 시술 횟수'].apply(removeHangual)
df.loc[:,['클리닉 내 총 시술 횟수']] = df['클리닉 내 총 시술 횟수'].apply(removeHangual)
df.loc[:,['IVF 시술 횟수']] = df['IVF 시술 횟수'].apply(removeHangual)
df.loc[:,['DI 시술 횟수']] = df['DI 시술 횟수'].apply(removeHangual)
df.loc[:,['총 임신 횟수']] = df['총 임신 횟수'].apply(removeHangual)
df.loc[:,['IVF 임신 횟수']] = df['IVF 임신 횟수'].apply(removeHangual)
df.loc[:,['DI 임신 횟수']] = df['DI 임신 횟수'].apply(removeHangual)
df.loc[:,['총 출산 횟수']] = df['총 출산 횟수'].apply(removeHangual)
df.loc[:,['IVF 출산 횟수']] = df['IVF 출산 횟수'].apply(removeHangual)
df.loc[:,['DI 출산 횟수']] = df['DI 출산 횟수'].apply(removeHangual)

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df.loc[:,'난자 출처'] = encoder.fit_transform(df['난자 출처'])
df.loc[:,'정자 출처'] = encoder.fit_transform(df['정자 출처'])
df.loc[:,'난자 기증자 나이'] = encoder.fit_transform(df['난자 기증자 나이'])
df.loc[:,'정자 기증자 나이'] = encoder.fit_transform(df['정자 기증자 나이'])

# %%
df.head(100)
# Out:
#    시술 당시 나이 시술 유형  특정 시술 유형  배란 자극 여부  이식된 배아 수  단일 배아 이식 여부  \
# 0       0.0   IVF      ICSI         1       2.0          0.0
# 1       5.0   IVF      ICSI         0       0.0          0.0
# 2       0.0   IVF       IVF         1       2.0          0.0
# 3       1.0   IVF      ICSI         1       0.0          0.0
# 4       0.0   IVF      ICSI         1       2.0          0.0
# ..      ...   ...       ...       ...       ...          ...
# 95      3.0   IVF       IVF         0       0.0          0.0
# 96      0.0   IVF  ICSI:IVF         1       0.0          0.0
# 97      4.0   IVF      ICSI         1       2.0          0.0
# 98      0.0   IVF       IVF         1       0.0          0.0
# 99      0.0   IVF   Unknown         0       2.0          0.0
#
#     착상 전 유전 검사 사용 여부  착상 전 유전 진단 사용 여부  남성 주 불임 원인  남성 부 불임 원인  ...  \
# 0                NaN               0.0           0           0  ...
# 1                NaN               0.0           0           0  ...
# 2                NaN               0.0           0           0  ...
# 3                NaN               0.0           0           0  ...
# 4                NaN               0.0           0           0  ...
# ..               ...               ...         ...         ...  ...
# 95               NaN               0.0           0           0  ...
# 96               NaN               0.0           0           0  ...
# 97               NaN               0.0           0           0  ...
# 98               NaN               0.0           0           0  ...
# 99               NaN               0.0           0           0  ...
#
#     기증 배아 사용 여부  대리모 여부  PGD 시술 여부  PGS 시술 여부  난자 채취 경과일  난자 해동 경과일  \
# 0           0.0     0.0        NaN        NaN        0.0        NaN
# 1           0.0     0.0        NaN        NaN        0.0        NaN
# 2           0.0     0.0        NaN        NaN        0.0        NaN
# 3           0.0     0.0        NaN        NaN        0.0        NaN
# 4           0.0     0.0        NaN        NaN        0.0        NaN
# ..          ...     ...        ...        ...        ...        ...
# 95          0.0     0.0        NaN        NaN        0.0        NaN
# 96          0.0     0.0        NaN        NaN        0.0        NaN
# 97          0.0     0.0        NaN        NaN        0.0        NaN
# 98          0.0     0.0        NaN        NaN        0.0        NaN
# 99          0.0     0.0        NaN        NaN        NaN        NaN
#
#     난자 혼합 경과일  배아 이식 경과일  배아 해동 경과일  임신 성공 여부
# 0         0.0        3.0        NaN         0
# 1         0.0        NaN        NaN         0
# 2         0.0        2.0        NaN         0
# 3         0.0        NaN        NaN         0
# 4         0.0        3.0        NaN         0
# ..        ...        ...        ...       ...
# 95        0.0        NaN        NaN         0
# 96        0.0        NaN        NaN         0
# 97        0.0        2.0        NaN         0
# 98        NaN        NaN        NaN         0
# 99        NaN        0.0        0.0         0
#
# [100 rows x 64 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df.loc[:,'시술 유형'] = encoder.fit_transform(df['시술 유형'])
df.loc[:,'특정 시술 유형'] = encoder.fit_transform(df['특정 시술 유형'])

# %% [markdown]
# # AUTOENCODER 결측치 처리

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# %%
missing_mask = df.isnull()

df_filled = df.fillna(0)

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_filled)

X_train, X_test = train_test_split(df_scaled, test_size=0.2, random_state=42)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20632\238711249.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_filled = df.fillna(0)

# %%
input_dim = X_train.shape[1]
encoding_dim = 32  


input_layer = Input(shape=(input_dim,))
encoder = Dense(encoding_dim, activation="relu")(input_layer)


decoder = Dense(input_dim, activation="sigmoid")(encoder)


autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.9174 - val_loss: 0.6639
# Epoch 2/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6712 - val_loss: 0.6478
# Epoch 3/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6558 - val_loss: 0.6417
# Epoch 4/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - loss: 0.6530 - val_loss: 0.6388
# Epoch 5/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6807 - val_loss: 0.6370
# Epoch 6/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.7234 - val_loss: 0.6357
# Epoch 7/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6498 - val_loss: 0.6348
# Epoch 8/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6868 - val_loss: 0.6342
# Epoch 9/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6536 - val_loss: 0.6337
# Epoch 10/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6418 - val_loss: 0.6334
# Epoch 11/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6881 - val_loss: 0.6332
# Epoch 12/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6535 - val_loss: 0.6329
# Epoch 13/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6469 - val_loss: 0.6328
# Epoch 14/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6489 - val_loss: 0.6326
# Epoch 15/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 0.6680 - val_loss: 0.6325
# Epoch 16/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.7844 - val_loss: 0.6324
# Epoch 17/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6325 - val_loss: 0.6323
# Epoch 18/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6554 - val_loss: 0.6323
# Epoch 19/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6342 - val_loss: 0.6322
# Epoch 20/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6747 - val_loss: 0.6322
# Epoch 21/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6595 - val_loss: 0.6321
# Epoch 22/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6372 - val_loss: 0.6321
# Epoch 23/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6607 - val_loss: 0.6321
# Epoch 24/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6548 - val_loss: 0.6320
# Epoch 25/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6678 - val_loss: 0.6320
# Epoch 26/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6552 - val_loss: 0.6320
# Epoch 27/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6327 - val_loss: 0.6319
# Epoch 28/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6630 - val_loss: 0.6319
# Epoch 29/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6591 - val_loss: 0.6319
# Epoch 30/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6763 - val_loss: 0.6319
# Epoch 31/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6556 - val_loss: 0.6318
# Epoch 32/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.7003 - val_loss: 0.6318
# Epoch 33/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6444 - val_loss: 0.6318
# Epoch 34/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.7083 - val_loss: 0.6318
# Epoch 35/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6736 - val_loss: 0.6318
# Epoch 36/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 999us/step - loss: 0.6502 - val_loss: 0.6318
# Epoch 37/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6828 - val_loss: 0.6318
# Epoch 38/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6907 - val_loss: 0.6317
# Epoch 39/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 996us/step - loss: 0.7283 - val_loss: 0.6317
# Epoch 40/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6556 - val_loss: 0.6317
# Epoch 41/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6576 - val_loss: 0.6317
# Epoch 42/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6561 - val_loss: 0.6317
# Epoch 43/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6884 - val_loss: 0.6317
# Epoch 44/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6640 - val_loss: 0.6317
# Epoch 45/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6553 - val_loss: 0.6317
# Epoch 46/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6384 - val_loss: 0.6317
# Epoch 47/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6783 - val_loss: 0.6317
# Epoch 48/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6397 - val_loss: 0.6316
# Epoch 49/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6363 - val_loss: 0.6316
# Epoch 50/50
# 802/802 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6982 - val_loss: 0.6316

# %%
missing_mask = df.isnull()

df_filled = df.fillna(0)

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_filled)

df_reconstructed = autoencoder.predict(df_scaled)

df_reconstructed = scaler.inverse_transform(df_reconstructed)

df_filled = df_filled.mask(missing_mask, df_reconstructed)

df_filled
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20632\2515822645.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_filled = df.fillna(0)
# 8011/8011 ━━━━━━━━━━━━━━━━━━━━ 4s 507us/step
#         시술 당시 나이  시술 유형  특정 시술 유형  배란 자극 여부  이식된 배아 수  단일 배아 이식 여부  \
# 0            0.0      1         4         1       2.0          0.0
# 1            5.0      1         4         0       0.0          0.0
# 2            0.0      1        15         1       2.0          0.0
# 3            1.0      1         4         1       0.0          0.0
# 4            0.0      1         4         1       2.0          0.0
# ...          ...    ...       ...       ...       ...          ...
# 256346       0.0      1         4         1       2.0          0.0
# 256347       2.0      1         4         1       2.0          0.0
# 256348       1.0      1         4         1       2.0          0.0
# 256349       2.0      1         4         1       2.0          0.0
# 256350       1.0      1        15         0       2.0          0.0
#
#         착상 전 유전 검사 사용 여부  착상 전 유전 진단 사용 여부  남성 주 불임 원인  남성 부 불임 원인  ...  \
# 0               0.010603               0.0           0           0  ...
# 1               0.010603               0.0           0           0  ...
# 2               0.010603               0.0           0           0  ...
# 3               0.010603               0.0           0           0  ...
# 4               0.010603               0.0           0           0  ...
# ...                  ...               ...         ...         ...  ...
# 256346          0.010603               0.0           0           0  ...
# 256347          0.010603               0.0           0           0  ...
# 256348          0.010603               0.0           0           0  ...
# 256349          0.010603               0.0           0           0  ...
# 256350          0.010603               0.0           0           0  ...
#
#         기증 배아 사용 여부  대리모 여부  PGD 시술 여부  PGS 시술 여부     난자 채취 경과일  난자 해동 경과일  \
# 0               0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 1               0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 2               0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 3               0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 4               0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# ...             ...     ...        ...        ...           ...        ...
# 256346          0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 256347          0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 256348          0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 256349          0.0     0.0     0.0085   0.007525  0.000000e+00   0.000008
# 256350          0.0     0.0     0.0085   0.007525  3.574374e-12   0.000008
#
#         난자 혼합 경과일  배아 이식 경과일  배아 해동 경과일  임신 성공 여부
# 0        0.000000   3.000000   0.007185         0
# 1        0.000000   2.701609   0.007185         0
# 2        0.000000   2.000000   0.007185         0
# 3        0.000000   2.701609   0.007185         0
# 4        0.000000   3.000000   0.007185         0
# ...           ...        ...        ...       ...
# 256346   0.000000   5.000000   0.007185         0
# 256347   0.000000   3.000000   0.007185         1
# 256348   0.000000   3.000000   0.007185         0
# 256349   0.000000   1.000000   0.007185         1
# 256350   0.004256   0.000000   0.000000         1
#
# [256351 rows x 64 columns]

# %%
target = df_filled['임신 성공 여부']
df_filled = df_filled.drop(columns=['임신 성공 여부'],axis=1)

# %% [markdown]
# # RANDOMFOREST 돌려보기

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score


X = df_filled
y = target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


class_weights = {0:1, 1:10}


rf_model = RandomForestClassifier(n_estimators=100, random_state=42, class_weight=class_weights)


rf_model.fit(X_train, y_train)


y_pred = rf_model.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

f1 = f1_score(y_test, y_pred, average='weighted')
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 77.50%
# F1 Score: 0.75

# %% [markdown]
# # RandomForest with Optuna

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer

X = df_filled
y = target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 5, 20)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])

    rf_model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )
    rf_model.fit(X_train, y_train)

    y_prob = rf_model.predict_proba(X_test)

    # 다중 클래스 분류의 경우 roc_auc_score 계산
    if len(set(y)) > 2:
        lb = LabelBinarizer()
        y_test_bin = lb.fit_transform(y_test)
        roc_auc = roc_auc_score(y_test_bin, y_prob, multi_class='ovr')
    else:
        roc_auc = roc_auc_score(y_test, y_prob[:, 1])

    return roc_auc

study = optuna.create_study(direction='maximize') 
study.optimize(objective, n_trials=50)

print("Best Hyperparameters:", study.best_params)
print("Best ROC-AUC Score: {:.4f}".format(study.best_value))
# Out:
# [I 2025-02-05 21:13:10,371] A new study created in memory with name: no-name-71054682-938c-4ac2-882e-8e4860e65cd4
# [I 2025-02-05 21:13:21,243] Trial 0 finished with value: 0.8040578486499034 and parameters: {'n_estimators': 64, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:13:45,159] Trial 1 finished with value: 0.7787913082316358 and parameters: {'n_estimators': 187, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:14:23,806] Trial 2 finished with value: 0.7561884753080896 and parameters: {'n_estimators': 73, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:15:06,536] Trial 3 finished with value: 0.7464098929451277 and parameters: {'n_estimators': 93, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:17:19,532] Trial 4 finished with value: 0.7919465249389708 and parameters: {'n_estimators': 171, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:17:41,937] Trial 5 finished with value: 0.7811975759577919 and parameters: {'n_estimators': 179, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:17:56,192] Trial 6 finished with value: 0.7362755801988488 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:18:00,706] Trial 7 finished with value: 0.7497718867419801 and parameters: {'n_estimators': 51, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:18:17,843] Trial 8 finished with value: 0.761728109451936 and parameters: {'n_estimators': 193, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:18:24,065] Trial 9 finished with value: 0.764081571292909 and parameters: {'n_estimators': 66, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: 0.8040578486499034.
# [I 2025-02-05 21:18:46,696] Trial 10 finished with value: 0.8108801824151903 and parameters: {'n_estimators': 133, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:19:09,169] Trial 11 finished with value: 0.810325490236291 and parameters: {'n_estimators': 133, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:19:31,184] Trial 12 finished with value: 0.8071688754898277 and parameters: {'n_estimators': 135, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:19:52,241] Trial 13 finished with value: 0.8013343549511274 and parameters: {'n_estimators': 138, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:20:09,362] Trial 14 finished with value: 0.7978605539154944 and parameters: {'n_estimators': 113, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:20:28,145] Trial 15 finished with value: 0.7880862758840859 and parameters: {'n_estimators': 160, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:20:48,045] Trial 16 finished with value: 0.7908578813568267 and parameters: {'n_estimators': 117, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:21:20,013] Trial 17 finished with value: 0.8016616614019252 and parameters: {'n_estimators': 153, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:21:34,946] Trial 18 finished with value: 0.7924309416961016 and parameters: {'n_estimators': 101, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.8108801824151903.
# [I 2025-02-05 21:24:23,581] Trial 19 finished with value: 0.8217367414489115 and parameters: {'n_estimators': 144, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:26:43,782] Trial 20 finished with value: 0.8177609024405977 and parameters: {'n_estimators': 151, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:28:59,561] Trial 21 finished with value: 0.8177651185867065 and parameters: {'n_estimators': 152, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:31:13,593] Trial 22 finished with value: 0.8177609024405977 and parameters: {'n_estimators': 151, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:33:40,080] Trial 23 finished with value: 0.8167226109836396 and parameters: {'n_estimators': 166, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:35:45,517] Trial 24 finished with value: 0.8133024729957121 and parameters: {'n_estimators': 147, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:37:43,403] Trial 25 finished with value: 0.8196934908693637 and parameters: {'n_estimators': 118, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:39:33,683] Trial 26 finished with value: 0.8196703188210004 and parameters: {'n_estimators': 122, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 19 with value: 0.8217367414489115.
# [I 2025-02-05 21:40:59,049] Trial 27 finished with value: 0.8231353683331062 and parameters: {'n_estimators': 90, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 27 with value: 0.8231353683331062.
# [I 2025-02-05 21:42:34,807] Trial 28 finished with value: 0.8225538144268396 and parameters: {'n_estimators': 96, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 27 with value: 0.8231353683331062.
# [I 2025-02-05 21:44:19,552] Trial 29 finished with value: 0.8224375313358159 and parameters: {'n_estimators': 86, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 27 with value: 0.8231353683331062.
# [I 2025-02-05 21:45:42,190] Trial 30 finished with value: 0.8217126615313954 and parameters: {'n_estimators': 84, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 27 with value: 0.8231353683331062.
# [I 2025-02-05 21:47:21,074] Trial 31 finished with value: 0.8226389495369587 and parameters: {'n_estimators': 104, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 27 with value: 0.8231353683331062.
# [I 2025-02-05 21:49:02,016] Trial 32 finished with value: 0.8234686052550567 and parameters: {'n_estimators': 105, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.8234686052550567.
# [I 2025-02-05 21:50:41,811] Trial 33 finished with value: 0.8226644695227858 and parameters: {'n_estimators': 106, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 32 with value: 0.8234686052550567.
# [I 2025-02-05 21:52:25,291] Trial 34 finished with value: 0.823529415733051 and parameters: {'n_estimators': 108, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 34 with value: 0.823529415733051.
# [I 2025-02-05 21:54:35,976] Trial 35 finished with value: 0.8219766384869727 and parameters: {'n_estimators': 109, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 34 with value: 0.823529415733051.
# [I 2025-02-05 21:56:10,747] Trial 36 finished with value: 0.8231050748691604 and parameters: {'n_estimators': 79, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 34 with value: 0.823529415733051.
# [I 2025-02-05 21:57:46,810] Trial 37 finished with value: 0.8249158783170107 and parameters: {'n_estimators': 79, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 37 with value: 0.8249158783170107.
# [I 2025-02-05 21:58:40,791] Trial 38 finished with value: 0.7746234674639592 and parameters: {'n_estimators': 70, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 37 with value: 0.8249158783170107.
# [I 2025-02-05 22:00:15,189] Trial 39 finished with value: 0.8250505366091361 and parameters: {'n_estimators': 91, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:01:11,256] Trial 40 finished with value: 0.8243771238935231 and parameters: {'n_estimators': 57, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:02:06,572] Trial 41 finished with value: 0.8244385097815435 and parameters: {'n_estimators': 56, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:03:00,517] Trial 42 finished with value: 0.8249158941903909 and parameters: {'n_estimators': 54, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:03:53,844] Trial 43 finished with value: 0.8249158941903909 and parameters: {'n_estimators': 54, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:04:01,250] Trial 44 finished with value: 0.7931912016422416 and parameters: {'n_estimators': 59, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:04:54,147] Trial 45 finished with value: 0.8248406645103421 and parameters: {'n_estimators': 53, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:05:13,384] Trial 46 finished with value: 0.7349526305358343 and parameters: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 39 with value: 0.8250505366091361.
# [I 2025-02-05 22:06:30,873] Trial 47 finished with value: 0.827198028998168 and parameters: {'n_estimators': 77, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 47 with value: 0.827198028998168.
# [I 2025-02-05 22:06:40,224] Trial 48 finished with value: 0.7875589335389903 and parameters: {'n_estimators': 78, 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 47 with value: 0.827198028998168.
# [I 2025-02-05 22:07:48,166] Trial 49 finished with value: 0.8269412021184429 and parameters: {'n_estimators': 65, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 47 with value: 0.827198028998168.
# Best Hyperparameters: {'n_estimators': 77, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None}
# Best ROC-AUC Score: 0.8272
